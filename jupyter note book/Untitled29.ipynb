# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Specify the path to your CSV file
file_path = r'R:\ML\DEEP learning\csv\customer_churn.csv'

# Load the CSV file into a DataFrame
df= pd.read_csv(file_path)

df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2539  2050-ONYDQ  Female              0     Yes        Yes      65
# 6950  2075-RMJIK  Female              0     Yes        Yes       5
# 4478  0988-JRWWP  Female              0      No         No       3
# 6799  8071-SBTRN  Female              0      No         No      70
# 1172  1641-RQDAY  Female              1     Yes        Yes      32
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 2539          Yes           Yes              No  No internet service  ...
# 6950          Yes            No             DSL                  Yes  ...
# 4478          Yes            No             DSL                   No  ...
# 6799          Yes           Yes     Fiber optic                  Yes  ...
# 1172          Yes           Yes     Fiber optic                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 2539  No internet service  No internet service  No internet service
# 6950                   No                   No                   No
# 4478                   No                   No                  Yes
# 6799                  Yes                   No                  Yes
# 1172                   No                   No                  Yes
#
#           StreamingMovies        Contract PaperlessBilling  \
# 2539  No internet service        Two year               No
# 6950                   No  Month-to-month              Yes
# 4478                   No  Month-to-month              Yes
# 6799                  Yes        Two year              Yes
# 1172                  Yes  Month-to-month              Yes
#
#                 PaymentMethod MonthlyCharges  TotalCharges Churn
# 2539  Credit card (automatic)          26.00       1654.85    No
# 6950             Mailed check          49.40        232.55    No
# 4478         Electronic check          54.20         140.4    No
# 6799             Mailed check         111.15       7737.55    No
# 1172         Electronic check         100.40       3217.65    No
#
# [5 rows x 21 columns]

# %%
df.Churn.value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df.shape[0]
# Out:
# 7043
