# %%
#knn calculates distance between test data and given training data
#knn are lazy learner
#value o k should not be high or very low
#How KNN Works
#Choosing the Number of Neighbors (K):==>select the number of nearest neighbors (K) that will be used in the prediction,small value of K can be noisy and subject to overfitting, while a large K can make it computationally expensive 
#Calculating Distance:===>KNN uses a distance metric to measure the similarity between the data points
#Finding the Neighbors==>NN calculates the distance between the data point and all the points in the training set. It then selects the K data points that are closest to the new data point
#Averaging for Regression:==> KNN predicts the value by averaging the values of K nearest neighbors.

# %% [markdown]
# ![4.png](attachment:4.png)

# %% [markdown]
# ![6.png](attachment:6.png)

# %% [markdown]
# ![2.png](attachment:2.png)

# %% [markdown]
# # Short Notes

# %%
#create data frame and add target after creating dataframe frim iris dataset
#find target col conation how many unique value
#add flower name colm based on target value
#take 3 dataframe and drawscatter plot of each dataframe
#Create KNN (K Neighrest Neighbour Classifier)
#predicts score then create confusion matrix and draw heatmap

# %% [markdown]
# # Question

# %% [markdown]
# df['flower_name'] =df.target.apply(lambda x: iris.target_names[x])
#
# df1 = df[50:100]
#
# df_versicolor = df[df['flower_name'] == 'versicolor']
#
# df_target_1 = df[df['target'] == 1]  # versicolor
#
# plt.scatter(df0['sepal length (cm)'], df0['sepal width (cm)'],color="green",marker='+')
#
# plt.scatter(df1['sepal length (cm)'], df1['sepal width (cm)'],color="blue",marker='.')

# %%
import pandas as pd
from sklearn.datasets import load_iris
iris = load_iris()

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
df = pd.DataFrame(iris.data,columns=iris.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df['target'] = iris.target
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df[df.target==1].head()
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 50                7.0               3.2                4.7               1.4
# 51                6.4               3.2                4.5               1.5
# 52                6.9               3.1                4.9               1.5
# 53                5.5               2.3                4.0               1.3
# 54                6.5               2.8                4.6               1.5
#
#     target
# 50       1
# 51       1
# 52       1
# 53       1
# 54       1

# %%
df[df.target==2].head()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 100                6.3               3.3                6.0               2.5
# 101                5.8               2.7                5.1               1.9
# 102                7.1               3.0                5.9               2.1
# 103                6.3               2.9                5.6               1.8
# 104                6.5               3.0                5.8               2.2
#
#      target
# 100       2
# 101       2
# 102       2
# 103       2
# 104       2

# %%
df['flower_name'] =df.target.apply(lambda x: iris.target_names[x])
## Define the mapping array
#fruit_names = ["Apple", "Banana", "Cherry"]

# Define an array of numbers representing fruits
#fruit_indices = [0, 2, 1, 0, 1]

# Map each number to its corresponding fruit name
#mapped_fruits = [fruit_names[index] for index in fruit_indices]
#output==>['Apple', 'Cherry', 'Banana', 'Apple', 'Banana']
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target flower_name
# 0       0      setosa
# 1       0      setosa
# 2       0      setosa
# 3       0      setosa
# 4       0      setosa

# %%
df[45:55]
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 45                4.8               3.0                1.4               0.3
# 46                5.1               3.8                1.6               0.2
# 47                4.6               3.2                1.4               0.2
# 48                5.3               3.7                1.5               0.2
# 49                5.0               3.3                1.4               0.2
# 50                7.0               3.2                4.7               1.4
# 51                6.4               3.2                4.5               1.5
# 52                6.9               3.1                4.9               1.5
# 53                5.5               2.3                4.0               1.3
# 54                6.5               2.8                4.6               1.5
#
#     target flower_name
# 45       0      setosa
# 46       0      setosa
# 47       0      setosa
# 48       0      setosa
# ...

# %%
df0 = df[:50]
df1 = df[50:100]
df2 = df[100:]

# %%
df_setosa = df[df['flower_name'] == 'setosa']
df_versicolor = df[df['flower_name'] == 'versicolor']
df_virginica = df[df['flower_name'] == 'virginica']  # If you have virginica species

# %%
df_target_0 = df[df['target'] == 0]  # setosa
df_target_1 = df[df['target'] == 1]  # versicolor
df_target_2 = df[df['target'] == 2]  # virginica (if exists in the dataset)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Sepal length vs Sepal Width (Setosa vs Versicolor)

# %%
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.scatter(df0['sepal length (cm)'], df0['sepal width (cm)'],color="green",marker='+')
plt.scatter(df1['sepal length (cm)'], df1['sepal width (cm)'],color="blue",marker='.')

# %%
#Petal length vs Pepal Width (Setosa vs Versicolor)

# %%
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.scatter(df0['petal length (cm)'], df0['petal width (cm)'],color="green",marker='+')
plt.scatter(df1['petal length (cm)'], df1['petal width (cm)'],color="blue",marker='.')

# %%
#Train test split

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop(['target','flower_name'], axis='columns')
y = df.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
len(X_train)
# Out:
# 120

# %%
len(X_test)
# Out:
# 30

# %%
#Create KNN (K Neighrest Neighbour Classifier)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=10)
#The prediction process essentially involves measuring the distance from the new data point to all points in the training set,
#selecting the 10 closest points (as specified by n_neighbors=10), 
#and then assigning a class based on the most frequent class label among these neighbors

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
knn.score(X_test, y_test)
# Out:
# 0.9666666666666667

# %%
knn.predict([[4.8,3.0,1.5,0.3]]) #. Here, 0 corresponds to the class setosa
# Out:
# C:\Users\rakes\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
#Plot Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
y_pred = knn.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[11,  0,  0],
#        [ 0, 12,  1],
#        [ 0,  0,  6]], dtype=int64)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sn
plt.figure(figsize=(7,5))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(58.222222222222214, 0.5, 'Truth')

# %%
#Print classification report for precesion, recall and f1-score for each classes

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      0.92      0.96        13
#            2       0.86      1.00      0.92         6
#
#     accuracy                           0.97        30
#    macro avg       0.95      0.97      0.96        30
# weighted avg       0.97      0.97      0.97        30
