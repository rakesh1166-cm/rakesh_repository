# %% [markdown]
# # Short notes

# %% [markdown]
# read csv file
#
# perform preprocessing and visulization task
#
# 1.how many null value in each col
#
# 2.how many unique value in particular or each colm
#
# 3.find sum of  all value in each colm seprately
#
# 4.find count each val of col by using value_counts
#
# determine shape or no of row and col after filtering of particular colm
#
# determine mean value of number not categorical colunm then groupby some particular colm
#
# determine Impact of salary,dept on employee retention by draw bar plot using crosstab
#
# determine Impact of all col on employee retention by draw  subplot bar plot using crosstab  and for loop
#
# take few col as faeture or X that impacts on target variable
#
# convert categorical data using dummies then concat
#
# trained given data on linear regression object to generate model
#
# predict single element or whole dataframe and score
#
# then determine confusion matrix and draw heatmap

# %% [markdown]
# # Question

# %% [markdown]
# df.isnull().sum()
#
# for i in df.columns:
#
#     print(df[i].sum())
#
# df['Department'].nunique()
#
# df.nunique()
#
# for i in df.columns:
#
#    print(df[i].value_counts())
#
# left = df[df.left==1]
#
# left.shape
#
# numeric_cols = df.select_dtypes(include=['number']).columns
#
# grouped_means = df.groupby('left')[numeric_cols].mean()
# grouped_means
#
# pd.crosstab(df.salary,df.left).plot(kind='bar')
#
# cm = confusion_matrix(y_test, y_predicted)
#
# sn.heatmap(cm, annot=True)

# %% [markdown]
# import pandas as pd
# import numpy as np
# from sklearn import linear_model
# import matplotlib.pyplot as plt
# from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# Specify the path to your CSV file
file_path = r'R:\ML\ML nd Dl by codebasics\csv\HR_comma_sep.csv'

# Load the CSV file into a DataFrame
df= pd.read_csv(file_path)
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Department               0
# salary                   0
# dtype: int64

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Department', 'salary'],
#       dtype='object')

# %%
for i in df.columns:
    print(df[i].sum())
# Out:
# 9191.89
# 10740.810000000001
# 57042
# 3015554
# 52470
# 2169
# 3571
# 319
# ...

# %%
df['Department'].nunique()
# Out:
# 10

# %%
df.nunique()
# Out:
# satisfaction_level        92
# last_evaluation           65
# number_project             6
# average_montly_hours     215
# time_spend_company         8
# Work_accident              2
# left                       2
# promotion_last_5years      2
# Department                10
# salary                     3
# dtype: int64

# %%
for i in df.columns:
    print(df[i].value_counts())
# Out:
# satisfaction_level
# 0.10    358
# 0.11    335
# 0.74    257
# 0.77    252
# 0.84    247
#        ...
# 0.25     34
# 0.28     31
# 0.27     30
# 0.26     30
# 0.12     30
# Name: count, Length: 92, dtype: int64
# last_evaluation
# 0.55    358
# 0.50    353
# 0.54    350
# 0.51    345
# 0.57    333
#        ...
# 0.39     52
# 0.43     50
# 0.38     50
# 0.44     44
# 0.36     22
# Name: count, Length: 65, dtype: int64
# number_project
# 4    4365
# 3    4055
# 5    2761
# 2    2388
# 6    1174
# 7     256
# Name: count, dtype: int64
# average_montly_hours
# 135    153
# 156    153
# 149    148
# 151    147
# 160    136
#       ...
# 297      7
# 288      6
# 299      6
# 96       6
# 303      6
# Name: count, Length: 215, dtype: int64
# time_spend_company
# 3     6443
# 2     3244
# 4     2557
# 5     1473
# 6      718
# 10     214
# 7      188
# 8      162
# Name: count, dtype: int64
# Work_accident
# 0    12830
# 1     2169
# Name: count, dtype: int64
# left
# 0    11428
# ...

# %%
left = df[df.left==1]
left.shape
# Out:
# (3571, 10)

# %%
retained = df[df.left==0]
retained.shape
# Out:
# (11428, 10)

# %%
numeric_cols = df.select_dtypes(include=['number']).columns
grouped_means = df.groupby('left')[numeric_cols].mean()
grouped_means
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# left
# 0               0.666810         0.715473        3.786664
# 1               0.440098         0.718113        3.855503
#
#       average_montly_hours  time_spend_company  Work_accident  left  \
# left
# 0               199.060203            3.380032       0.175009   0.0
# 1               207.419210            3.876505       0.047326   1.0
#
#       promotion_last_5years
# left
# 0                  0.026251
# 1                  0.005321

# %%
From above table we can draw following conclusions,

**Satisfaction Level**: Satisfaction level seems to be relatively low (0.44) in employees leaving the firm vs the retained ones (0.66)
**Average Monthly Hours**: Average monthly hours are higher in employees leaving the firm (199 vs 207)
**Promotion Last 5 Years**: Employees who are given promotion are likely to be retained at firm

# %%
#Impact of salary on employee retention
pd.crosstab(df.salary,df.left).plot(kind='bar')
# Out:
# <Axes: xlabel='salary'>

# %%
pd.crosstab(df.Department,df.left).plot(kind='bar')
# Out:
# <Axes: xlabel='Department'>

# %%
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(10, 15))  # Adjust figure size as necessary
ax = axes.flatten()  # Flatten the axes array for easy iteration

# Counter for the subplot index
index = 0

# Loop through each column in the DataFrame except 'left'
for column in df.columns:
    if column != 'left':  # Skip the 'left' column to avoid self-comparison
        # Generate the crosstab
        ct = pd.crosstab(df[column], df['left'])

        # Plot the crosstab on specified subplot axis
        ct.plot(kind='bar', ax=ax[index], title=f'Count of Left by {column}')
        ax[index].set_xlabel(column)  # Set x-label as the current column name
        ax[index].set_ylabel('Count')  # Set y-label as 'Count'
        ax[index].set_xticklabels(ax[index].get_xticklabels(), rotation=0)  # Manage x-tick labels

        # Increment subplot index
        index += 1

# Adjust layout to prevent overlap
plt.tight_layout()

# Display all plots
plt.show()

# %%
crosstab_result = pd.crosstab(grouped_means['left'], grouped_means['promotion_last_5years'])
crosstab_result
# Out:
# promotion_last_5years  0.005321  0.026251
# left
# 0.0                           0         1
# 1.0                           1         0

# %%
columns_to_process = grouped_means.columns.difference(['left'])

# Set up the figure for subplots
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(10, 10))  # Adjust the figure size to your liking
axes = axes.flatten()  # Flatten the axes array for easy indexing

for idx, col in enumerate(columns_to_process):
    if idx < 16:  # We have space for only 16 plots
        # Data preparation for plotting
        heights = grouped_means[col].values  # Get the column values for heights
        x_labels = grouped_means['left'].values  # Corresponding 'left' values
        
        # Plotting the bar plot in a subplot
        axes[idx].bar(x_labels, heights, color=['blue', 'red'])
        axes[idx].set_title(f'{col}')
        axes[idx].set_xlabel('Left')
        axes[idx].set_xticks([0, 1])
        axes[idx].set_xticklabels(['0', '1'])
        axes[idx].set_ylabel('Value')

# Adjust layout and display
plt.tight_layout()
plt.show()

# %%
subdf = df[['satisfaction_level','average_montly_hours','promotion_last_5years','salary']]
subdf.head()
# Out:
#    satisfaction_level  average_montly_hours  promotion_last_5years  salary
# 0                0.38                   157                      0     low
# 1                0.80                   262                      0  medium
# 2                0.11                   272                      0  medium
# 3                0.72                   223                      0     low
# 4                0.37                   159                      0     low

# %%
salary_dummies = pd.get_dummies(subdf.salary, prefix="salary")
salary_dummies = salary_dummies.astype(int)

# %%
df_with_dummies = pd.concat([subdf,salary_dummies],axis='columns')

# %%
df_with_dummies.head()
# Out:
#    satisfaction_level  average_montly_hours  promotion_last_5years  salary  \
# 0                0.38                   157                      0     low
# 1                0.80                   262                      0  medium
# 2                0.11                   272                      0  medium
# 3                0.72                   223                      0     low
# 4                0.37                   159                      0     low
#
#    salary_high  salary_low  salary_medium
# 0            0           1              0
# 1            0           0              1
# 2            0           0              1
# 3            0           1              0
# 4            0           1              0

# %%
df_with_dummies.drop('salary',axis='columns',inplace=True)
df_with_dummies.head()
# Out:
#    satisfaction_level  average_montly_hours  promotion_last_5years  \
# 0                0.38                   157                      0
# 1                0.80                   262                      0
# 2                0.11                   272                      0
# 3                0.72                   223                      0
# 4                0.37                   159                      0
#
#    salary_high  salary_low  salary_medium
# 0            0           1              0
# 1            0           0              1
# 2            0           0              1
# 3            0           1              0
# 4            0           1              0

# %%
X = df_with_dummies
X.head()
# Out:
#    satisfaction_level  average_montly_hours  promotion_last_5years  \
# 0                0.38                   157                      0
# 1                0.80                   262                      0
# 2                0.11                   272                      0
# 3                0.72                   223                      0
# 4                0.37                   159                      0
#
#    salary_high  salary_low  salary_medium
# 0            0           1              0
# 1            0           0              1
# 2            0           0              1
# 3            0           1              0
# 4            0           1              0

# %%
y = df.left

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.3)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
#Accuracy of the model

# %%
model.score(X_test,y_test)
# Out:
# 0.7838095238095238

# %%
print("Column names:", X_test)
y_predicted = model.predict(X_test)
print("Column names:", y_predicted)
# Count the predicted results
predicted_counts = pd.Series(y_predicted).value_counts()
print("Column names:", predicted_counts)
# Plot the bar chart for predicted data
plt.figure(figsize=(7, 5))
predicted_counts.sort_index().plot(kind='bar', color=['red', 'green'])  # Adjust colors if needed
plt.title('Predicted left  Counts')
plt.xlabel('left company (1 = Yes, 0 = No)')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()
# Out:
# Column names:        satisfaction_level  average_montly_hours  promotion_last_5years  \
# 13744                0.60                   211                      0
# 3470                 0.34                   114                      0
# 5201                 0.36                   187                      0
# 1997                 0.41                   157                      0
# 1467                 0.10                   272                      0
# ...                   ...                   ...                    ...
# 4065                 0.83                   247                      0
# 399                  0.10                   250                      0
# 1426                 0.36                   138                      0
# 11047                0.36                   155                      0
# 973                  0.37                   150                      0
#
#        salary_high  salary_low  salary_medium
# 13744            0           1              0
# ...

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_predicted)
cm
#True Positives (TP): The model correctly predicted 7581 instances as positive.
#False Positives (FP): The model incorrectly predicted 419 instances as positive when they were actually negative.
#False Negatives (FN): The model incorrectly predicted 1851 instances as negative when they were actually positive.
#True Negatives (TN): The model correctly predicted 649 instances as negative.
# Out:
# array([[7581,  419],
#        [1851,  649]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
##for classifiction prob where multiple independent feature are there draw multiple barplot using crosstab, on subplots Or scatter plot 
##analyze how many type of each data in target colunm using value counts or left = df[df.left==1] thenleft.shape Or groupby target col display dataframe
#calculate  sum of each col using for loop
#calculate counts of each value  in col and encoding text value of independent feature
#draw heat map of confusion matrix to check accuracy of model
